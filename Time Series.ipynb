# %% [markdown]
# ## Time Series - Group Project (Merge datasets)

# %%
#Imports
import pandas as pd
pd.options.mode.chained_assignment = None
#Filenames
POPULATION_FILENAME = "Country-Population.xls"
FERTILITYRATE_FILENAME = "Fertility-Rate.xls"
LIFEEXPECTANCY_FILENAME = "Life-Expectancy-At-Birth.xls"
#Import all data
population = pd.read_excel(POPULATION_FILENAME, header = 0)
population.set_index("Country Name", inplace=True)
fertilityRate = pd.read_excel(FERTILITYRATE_FILENAME, header = 0)
fertilityRate.set_index("Country Name", inplace=True)
lifeExpectancy = pd.read_excel(LIFEEXPECTANCY_FILENAME, header = 0)
lifeExpectancy.set_index("Country Name", inplace=True)

# %%
population.head()
# Out:
#              Country Code     Indicator Name Indicator Code       1960  \
# Country Name
# Aruba                 ABW  Population, total    SP.POP.TOTL    54208.0
# Andorra               AND  Population, total    SP.POP.TOTL    13414.0
# Afghanistan           AFG  Population, total    SP.POP.TOTL  8994793.0
# Angola                AGO  Population, total    SP.POP.TOTL  5270844.0
# Albania               ALB  Population, total    SP.POP.TOTL  1608800.0
#
#                    1961       1962       1963       1964       1965  \
# Country Name
# Aruba           55435.0    56226.0    56697.0    57029.0    57360.0
# Andorra         14376.0    15376.0    16410.0    17470.0    18551.0
# Afghanistan   9164945.0  9343772.0  9531555.0  9728645.0  9935358.0
# Angola        5367287.0  5465905.0  5565808.0  5665701.0  5765025.0
# Albania       1659800.0  1711319.0  1762621.0  1814135.0  1864791.0
#
#                     1966  ...        2004        2005        2006        2007  \
# ...

# %%
fertilityRate.head()
# Out:
#              Country Code                            Indicator Name  \
# Country Name
# Aruba                 ABW  Fertility rate, total (births per woman)
# Andorra               AND  Fertility rate, total (births per woman)
# Afghanistan           AFG  Fertility rate, total (births per woman)
# Angola                AGO  Fertility rate, total (births per woman)
# Albania               ALB  Fertility rate, total (births per woman)
#
#               Indicator Code   1960   1961   1962   1963   1964   1965   1966  \
# Country Name
# Aruba         SP.DYN.TFRT.IN  4.820  4.655  4.471  4.271  4.059  3.842  3.625
# Andorra       SP.DYN.TFRT.IN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan   SP.DYN.TFRT.IN  7.671  7.671  7.671  7.671  7.671  7.671  7.671
# Angola        SP.DYN.TFRT.IN  7.316  7.354  7.385  7.410  7.425  7.430  7.422
# Albania       SP.DYN.TFRT.IN  6.186  6.076  5.956  5.833  5.711  5.594  5.483
#
# ...

# %%
lifeExpectancy.head()
# Out:
#              Country Code                           Indicator Name  \
# Country Name
# Aruba                 ABW  Life expectancy at birth, total (years)
# Andorra               AND  Life expectancy at birth, total (years)
# Afghanistan           AFG  Life expectancy at birth, total (years)
# Angola                AGO  Life expectancy at birth, total (years)
# Albania               ALB  Life expectancy at birth, total (years)
#
#               Indicator Code       1960       1961       1962       1963  \
# Country Name
# Aruba         SP.DYN.LE00.IN  65.569366  65.988024  66.365537  66.713976
# Andorra       SP.DYN.LE00.IN        NaN        NaN        NaN        NaN
# Afghanistan   SP.DYN.LE00.IN  31.580049  32.095976  32.611878  33.127317
# Angola        SP.DYN.LE00.IN  32.984829  33.386220  33.787585  34.188463
# Albania       SP.DYN.LE00.IN  62.254366  63.273463  64.162854  64.887098
#
#                    1964       1965       1966  ...       2004       2005  \
# ...

# %%
#Countries we want to visualize
countriesToVisualize = ["United States"]
#Columns these columns
dropColumns = ["Country Code", "Indicator Name", "Indicator Code"]

# %%
#Grab all data associated with countries (countriesToVisualize)
populationData = population.loc[population.index.isin(countriesToVisualize)]
fertilityRateData = fertilityRate.loc[fertilityRate.index.isin(countriesToVisualize)]
lifeExpectancyData = lifeExpectancy.loc[lifeExpectancy.index.isin(countriesToVisualize)]

# %%
#Drop unnecessary columns and apply transpose
populationData.drop(dropColumns, axis=1, inplace= True)
populationData.index = "Population_" + populationData.index.astype(str)
populationData = populationData.transpose().rename_axis('Year', axis=1)
populationData = populationData.astype(int)
populationData
# Out:
# Year  Population_United States
# 1960                 180671000
# 1961                 183691000
# 1962                 186538000
# 1963                 189242000
# 1964                 191889000
# 1965                 194303000
# 1966                 196560000
# 1967                 198712000
# 1968                 200706000
# 1969                 202677000
# 1970                 205052000
# 1971                 207661000
# 1972                 209896000
# 1973                 211909000
# 1974                 213854000
# 1975                 215973000
# 1976                 218035000
# 1977                 220239000
# 1978                 222585000
# 1979                 225055000
# 1980                 227225000
# 1981                 229466000
# 1982                 231664000
# 1983                 233792000
# 1984                 235825000
# 1985                 237924000
# 1986                 240133000
# 1987                 242289000
# 1988                 244499000
# ...

# %%
#Drop unnecessary columns and apply transpose
fertilityRateData.drop(dropColumns, axis=1, inplace= True)
fertilityRateData.index = "FertilityRate_" + fertilityRateData.index.astype(str)
fertilityRateData = fertilityRateData.transpose().rename_axis('Year', axis=1)
fertilityRateData
# Out:
# Year  FertilityRate_United States
# 1960                       3.6540
# 1961                       3.6200
# 1962                       3.4610
# 1963                       3.3190
# 1964                       3.1900
# 1965                       2.9130
# 1966                       2.7210
# 1967                       2.5580
# 1968                       2.4640
# 1969                       2.4560
# 1970                       2.4800
# 1971                       2.2660
# 1972                       2.0100
# 1973                       1.8790
# 1974                       1.8350
# 1975                       1.7740
# 1976                       1.7380
# 1977                       1.7900
# 1978                       1.7600
# 1979                       1.8080
# 1980                       1.8395
# 1981                       1.8120
# 1982                       1.8275
# 1983                       1.7990
# 1984                       1.8065
# 1985                       1.8440
# ...

# %%
#Drop unnecessary columns and apply transpose
lifeExpectancyData.drop(dropColumns, axis=1, inplace= True)
lifeExpectancyData.index = "LifeExpectancy_" + lifeExpectancyData.index.astype(str)
lifeExpectancyData = lifeExpectancyData.transpose().rename_axis('Year', axis=1)
lifeExpectancyData
# Out:
# Year  LifeExpectancy_United States
# 1960                     69.770732
# 1961                     70.270732
# 1962                     70.119512
# 1963                     69.917073
# 1964                     70.165854
# 1965                     70.214634
# 1966                     70.212195
# 1967                     70.560976
# 1968                     69.951220
# 1969                     70.507317
# 1970                     70.807317
# 1971                     71.107317
# 1972                     71.156098
# 1973                     71.356098
# 1974                     71.956098
# 1975                     72.604878
# 1976                     72.856098
# 1977                     73.256098
# 1978                     73.356098
# 1979                     73.804878
# 1980                     73.658537
# 1981                     74.007317
# 1982                     74.360976
# 1983                     74.463415
# 1984                     74.563415
# 1985                     74.563415
# ...

# %%
#Merge all dataset
finalDataset = populationData.merge(fertilityRateData, left_index=True, right_index=True, how='inner').merge(lifeExpectancyData, left_index=True, right_index=True, how='inner')
finalDataset
# Out:
# Year  Population_United States  FertilityRate_United States  \
# 1960                 180671000                       3.6540
# 1961                 183691000                       3.6200
# 1962                 186538000                       3.4610
# 1963                 189242000                       3.3190
# 1964                 191889000                       3.1900
# 1965                 194303000                       2.9130
# 1966                 196560000                       2.7210
# 1967                 198712000                       2.5580
# 1968                 200706000                       2.4640
# 1969                 202677000                       2.4560
# 1970                 205052000                       2.4800
# 1971                 207661000                       2.2660
# 1972                 209896000                       2.0100
# 1973                 211909000                       1.8790
# 1974                 213854000                       1.8350
# ...

# %%
#Re-order year column and create a CSV
finalDataset.insert(loc=0, column="Year", value = finalDataset.index)
finalDataset.to_csv("TimeSeries.csv", index = False);
